# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

pd.set_option('display.max_columns', None)

train = pd.read_csv('train.csv')
holdout = pd.read_csv('test.csv')

holdout.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
# %load functions.py
def process_missing(df):
    """Handle various missing values from the data set

    Usage
    ------

    holdout = process_missing(holdout)
    """
    df["Fare"] = df["Fare"].fillna(train["Fare"].mean())
    df["Embarked"] = df["Embarked"].fillna("S")
    return df

def process_age(df):
    """Process the Age column into pre-defined 'bins' 

    Usage
    ------

    train = process_age(train)
    """
    df["Age"] = df["Age"].fillna(-0.5)
    cut_points = [-1,0,5,12,18,35,60,100]
    label_names = ["Missing","Infant","Child","Teenager","Young Adult","Adult","Senior"]
    df["Age_categories"] = pd.cut(df["Age"],cut_points,labels=label_names)
    return df

def process_fare(df):
    """Process the Fare column into pre-defined 'bins' 

    Usage
    ------

    train = process_fare(train)
    """
    cut_points = [-1,12,50,100,1000]
    label_names = ["0-12","12-50","50-100","100+"]
    df["Fare_categories"] = pd.cut(df["Fare"],cut_points,labels=label_names)
    return df

def process_cabin(df):
    """Process the Cabin column into pre-defined 'bins' 

    Usage
    ------

    train process_cabin(train)
    """
    df["Cabin_type"] = df["Cabin"].str[0]
    df["Cabin_type"] = df["Cabin_type"].fillna("Unknown")
    df = df.drop('Cabin',axis=1)
    return df

def process_titles(df):
    """Extract and categorize the title from the name column 

    Usage
    ------

    train = process_titles(train)
    """
    titles = {
        "Mr" :         "Mr",
        "Mme":         "Mrs",
        "Ms":          "Mrs",
        "Mrs" :        "Mrs",
        "Master" :     "Master",
        "Mlle":        "Miss",
        "Miss" :       "Miss",
        "Capt":        "Officer",
        "Col":         "Officer",
        "Major":       "Officer",
        "Dr":          "Officer",
        "Rev":         "Officer",
        "Jonkheer":    "Royalty",
        "Don":         "Royalty",
        "Sir" :        "Royalty",
        "Countess":    "Royalty",
        "Dona":        "Royalty",
        "Lady" :       "Royalty"
    }
    extracted_titles = df["Name"].str.extract(' ([A-Za-z]+)\.',expand=False)
    df["Title"] = extracted_titles.map(titles)
    return df

def create_dummies(df,column_name):
    """Create Dummy Columns (One Hot Encoding) from a single Column

    Usage
    ------

    train = create_dummies(train,"Age")
    """
    dummies = pd.get_dummies(df[column_name],prefix=column_name)
    df = pd.concat([df,dummies],axis=1)
    return df

# %%
def process_dataframe(df):
    df = process_missing(df)
    df = process_age(df)
    df = process_fare(df)
    df = process_cabin(df)
    df = process_titles(df)
    
    cat_column = ["Age_categories", "Fare_categories","Title", "Cabin_type","Sex"]
    
    for c in cat_column:
        df = create_dummies(df, c)
    return df

train = process_dataframe(train)
holdout = process_dataframe(holdout)

# %%
train[['SibSp', 'Parch']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 2 columns):
# SibSp    891 non-null int64
# Parch    891 non-null int64
# dtypes: int64(2)
# memory usage: 14.0 KB

# %%
fig, ax = plt.subplots(1,2)

ax[0].hist(train['SibSp'])
ax[1].hist(train['Parch'])
# Out:
# (array([678., 118.,   0.,  80.,   0.,   5.,   4.,   0.,   5.,   1.]),
#  array([0. , 0.6, 1.2, 1.8, 2.4, 3. , 3.6, 4.2, 4.8, 5.4, 6. ]),
#  <a list of 10 Patch objects>)

# %%
y1 = pd.pivot_table(train, index = 'SibSp', values = 'Survived') 
y2 = pd.pivot_table(train, index = 'Parch', values = 'Survived')

print(y1)
print(y2)
# Out:
#        Survived
# SibSp
# 0      0.345395
# 1      0.535885
# 2      0.464286
# 3      0.250000
# 4      0.166667
# 5      0.000000
# 8      0.000000
#        Survived
# Parch
# 0      0.343658
# 1      0.550847
# 2      0.500000
# 3      0.600000
# 4      0.000000
# 5      0.200000
# 6      0.000000

# %% [markdown]
# Looks like the % of survived is the highest for those who have 1 sibling/spouse and 1 parent/child(ren)

# %%
train['family'] = train[['SibSp', 'Parch']].sum(axis=1).copy()
holdout['family'] = holdout[['SibSp', 'Parch']].sum(axis=1).copy()

# %%
pivot = pd.pivot_table(train, index = 'family', values = 'Survived')
x = pivot.index
y = pivot['Survived']

plt.bar(x, y)
plt.xlabel('Family Members')
plt.ylabel('% survived')
# Out:
# Text(0,0.5,'% survived')

# %% [markdown]
# By adding the two columns together, we can see the total number of members in a family. In addition, we see that the graph is skewed to the right, meaning that most of the customers didn't have family on board.
#
# When we combine the two columns, we get those that had no family members only had a 30% of survival rate
#
# next, we will go ahead and create a new feature that determines if the passenger had a family member or not

# %%
def isalone(df):
    df['isalone'] = [1 if x == 0 else 0 for x in df['family']]
    df.loc[(df["family"] == 0),"isalone"] = 1
    df = df.drop("family",axis=1)
    return df


train = isalone(train)
holdout = isalone(holdout)

# %%
train.isnull().sum()
# Out:
# PassengerId                   0
# Survived                      0
# Pclass                        0
# Name                          0
# Sex                           0
# Age                           0
# SibSp                         0
# Parch                         0
# Ticket                        0
# Fare                          0
# Embarked                      0
# Age_categories                0
# Fare_categories               0
# Cabin_type                    0
# Title                         0
# Age_categories_Missing        0
# Age_categories_Infant         0
# Age_categories_Child          0
# Age_categories_Teenager       0
# Age_categories_Young Adult    0
# Age_categories_Adult          0
# Age_categories_Senior         0
# Fare_categories_0-12          0
# Fare_categories_12-50         0
# Fare_categories_50-100        0
# Fare_categories_100+          0
# Title_Master                  0
# Title_Miss                    0
# Title_Mr                      0
# ...

# %%
from sklearn.feature_selection import RFECV
from sklearn.ensemble import RandomForestClassifier

def select_features(df):
    df_numerical = df.select_dtypes([np.number]).dropna(axis=1)
    
    all_x = df_numerical.drop(columns = ['PassengerId', 'Survived'])
    all_y = df_numerical['Survived']

    rf = RandomForestClassifier(random_state = 1)
    
    selector = RFECV(rf, cv = 10)
    selector.fit(all_x, all_y)
    
    best_columns = list(all_x.columns[selector.support_])
    print ('The best columns are: \n {0}'.format(best_columns))
    
    return best_columns

# %%
features = select_features(train)
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# ...

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression




def select_model(df, features):
    
    models = [{"name": "KNeighborsClassifier",
           "estimator": KNeighborsClassifier(),
           "hyperparameters":{"n_neighbors": range(1,20,2),
                              "weights": ["distance", "uniform"],
                              'algorithm': ["ball_tree", "kd_tree", "brute"],
                              'p': [1,2]
                             }
          },
              
          {'name': 'LogisticRegression',
           'estimator': LogisticRegression(),
           'hyperparameters':{'solver': ["newton-cg", "lbfgs", "liblinear"]}
          },
              
          {'name': 'RandomForestClassifier',
           'estimator': RandomForestClassifier(),
           "hyperparameters": {"n_estimators": [4, 6, 9],
                               "criterion": ["entropy", "gini"],
                               "max_depth": [2, 5, 10],
                               "max_features": ["log2", "sqrt"],
                               "min_samples_leaf": [1, 5, 8],
                               "min_samples_split": [2, 3, 5]
                              }
          }
         ]
    
    
    all_X = df[features]
    all_y = df['Survived']
    
    
    predictions = []
    
    
    for m in models:
        print(m['name'])

        estimator = m['estimator']
        grid = GridSearchCV(estimator, m['hyperparameters'], cv=10)
        
        grid.fit(all_X, all_y)
        
        m["best_params"] = grid.best_params_
        m["best_score"] = grid.best_score_
        m["best_model"] = grid.best_estimator_
        
        print("Best Score: {}".format(m["best_score"]))
        print("Best Parameters: {}\n".format(m["best_params"]))
        
    return models
        
results = select_model(train, features)
# Out:
# KNeighborsClassifier
# /anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Best Score: 0.7755331088664422
# Best Parameters: {'algorithm': 'brute', 'n_neighbors': 5, 'p': 1, 'weights': 'uniform'}
#
# LogisticRegression
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ...

# %%
def save_submission_file(model, cols, filename = 'submission.csv'):
    test_x = holdout[cols]
    
    prediction = model.predict(test_x)
    
    df = {'PassengerID': holdout['PassengerId'],
         'Survived': prediction}
    
    submission = pd.DataFrame(df)
    submission.to_csv(filename, index=False)
    
best_model = results[2]['best_model']
save_submission_file(best_model, features)
